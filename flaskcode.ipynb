# %%
# Dependencies
import csv
import matplotlib.pyplot as plt
import requests
import pandas as pd
from pprint import pprint
from datetime import date
from datetime import datetime
import numpy as np

# %%
from flask import (
    Flask,
    render_template,
    jsonify,
    request)

from flask_sqlalchemy import SQLAlchemy

app = Flask(__name__)

app.config['SQLALCHEMY_DATABASE_URI'] = "sqlite:///db/db.sqlite"

db = SQLAlchemy(app)
# Out:
# C:\Users\aliqu\AppData\Local\Continuum\anaconda3\envs\py37\lib\site-packages\flask_sqlalchemy\__init__.py:835: FSADeprecationWarning: SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and will be disabled by default in the future.  Set it to True or False to suppress this warning.
#   'SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and '

# %%
#%%
# Dependencies
import csv
import matplotlib.pyplot as plt
import requests
import pandas as pd
from pprint import pprint
from datetime import date
from datetime import datetime
import numpy as np

#from config import api_key
#from config import weather_key


#%%
# OHLCV Historical URL
url_base = "https://rest.coinapi.io/v1/"
url_ohlcv = "ohlcv/"
asset_id_base = "BTC"
asset_id_quote = "USD"
period_id = "1DAY"
time_start = "2017-01-01T00:00:00"
time_end = "2017-02-01T00:00:00"
#time_end = ""
limit = "100" #cann be max of 100000
include_empty_items = False
ohlcv_hist_url = f'{url_base}{url_ohlcv}{asset_id_base}/{asset_id_quote}/history?period_id={period_id}&time_start={time_start}&time_end={time_end}&limit={limit}&include_empty_items={include_empty_items}'
#print(ohlcv_hist_url)
#%% 
# Test API Call for Crypto
headers = {'X-CoinAPI-Key' : "040C8FCD-C322-4168-97B8-27E979246DAF"}
response = requests.get(ohlcv_hist_url, headers=headers).json()

# Crypto Multiple Coins
coins = ["BTC", "ETH"]

# Set up lists to hold response info
close = []

# Loop
for coin in coins:
    response = requests.get(f'{url_base}{url_ohlcv}{coin}/{asset_id_quote}/history?period_id={period_id}&time_start={time_start}&time_end={time_end}&limit={limit}&include_empty_items={include_empty_items}', headers=headers).json()
    close.append(response[0]['price_close'])

print(f"The close prices for BTC then ETH: {close}")

str_d0 = time_start[0:10]
str_d1 = time_end[0:10]

d1 = datetime.strptime(str_d0, "%Y-%m-%d")
d2 = datetime.strptime(str_d1, "%Y-%m-%d")

d1 = d1.date()
d2 = d2.date()

delta  = d2 - d1
days  = delta.days

coins = ["BTC", "ETH"]

# Set up lists to hold response info
close = []

# Loop
for coin in coins:
    response = requests.get(f'{url_base}{url_ohlcv}{coin}/{asset_id_quote}/history?period_id={period_id}&time_start={time_start}&time_end={time_end}&limit={limit}&include_empty_items={include_empty_items}', headers=headers).json()
    close.append(response[0]['price_close'])

# for i in range(days):
#     print(i)
#%%
# Create Crypto Data Frame
coins_dict = {
    "coins": coins,
    "price_close": close
}

coins_df = pd.DataFrame(coins_dict)
coins_df.head()

#%%
str_d0 = time_start[0:10]
str_d1 = time_end[0:10]

d1 = datetime.strptime(str_d0, "%Y-%m-%d")
d2 = datetime.strptime(str_d1, "%Y-%m-%d")

d1 = d1.date()
d2 = d2.date()

delta  = d2 - d1
days  = delta.days

final_lst = []
row_list = []
dict_final = {}
lst=[]
lst = response


for coin in coins:
    response = requests.get(f'{url_base}{url_ohlcv}{coin}/{asset_id_quote}/history?period_id={period_id}&time_start={time_start}&time_end={time_end}&limit={limit}&include_empty_items={include_empty_items}', headers=headers).json()
    #print("coin is: " + coin)
    for i in range(len(lst)):
        row_list.append(coin)
        row_list.append(lst[i]['time_period_start'])
        row_list.append(lst[i]['price_close'])
        dict_final['coin']=coin

        # dict_final['time_start']=lst[i]['time_period_start']
        dict_final['time_start']=lst[i]['time_period_start'][0:10]
        dict_final['price_close']=lst[i]['price_close']
        final_lst.append(dict_final) 
        dict_final = {} 
# print(final_lst['coin'][0])       
print(final_lst)
# print(len(final_lst))  -- 837
#%%
# print(final_lst[0]['coin']) 
# print(final_lst[0]['time_start']) 
# print(final_lst[0]['price_close']) 

print(final_lst[1]['coin']) 
print(final_lst[1]['time_start']) 
print(final_lst[1]['price_close']) 

# print(len(final_lst)) 
# print(final_lst)
#%%
# Out:
# The close prices for BTC then ETH: [992.95, 8.18]
# [{'coin': 'BTC', 'time_start': '2017-01-01', 'price_close': 8.18}, {'coin': 'BTC', 'time_start': '2017-01-02', 'price_close': 8.38}, {'coin': 'BTC', 'time_start': '2017-01-03', 'price_close': 9.59}, {'coin': 'BTC', 'time_start': '2017-01-04', 'price_close': 11.17}, {'coin': 'BTC', 'time_start': '2017-01-05', 'price_close': 10.31859}, {'coin': 'BTC', 'time_start': '2017-01-06', 'price_close': 10.14}, {'coin': 'BTC', 'time_start': '2017-01-07', 'price_close': 9.92}, {'coin': 'BTC', 'time_start': '2017-01-08', 'price_close': 10.5}, {'coin': 'BTC', 'time_start': '2017-01-09', 'price_close': 10.343}, {'coin': 'BTC', 'time_start': '2017-01-10', 'price_close': 10.522}, {'coin': 'BTC', 'time_start': '2017-01-11', 'price_close': 9.7}, {'coin': 'BTC', 'time_start': '2017-01-12', 'price_close': 9.657}, {'coin': 'BTC', 'time_start': '2017-01-13', 'price_close': 9.699}, {'coin': 'BTC', 'time_start': '2017-01-14', 'price_close': 9.679}, {'coin': 'BTC', 'time_start': '2017-01-15', 'price_close': 9.728}, {'coin': 'BTC', 'time_start': '2017-01-16', 'price_close': 9.53}, {'coin': 'BTC', 'time_start': '2017-01-17', 'price_close': 10.292}, {'coin': 'BTC', 'time_start': '2017-01-18', 'price_close': 10.222}, {'coin': 'BTC', 'time_start': '2017-01-19', 'price_close': 10.44988}, {'coin': 'BTC', 'time_start': '2017-01-20', 'price_close': 10.62001}, {'coin': 'BTC', 'time_start': '2017-01-21', 'price_close': 10.949}, {'coin': 'BTC', 'time_start': '2017-01-22', 'price_close': 10.664}, {'coin': 'BTC', 'time_start': '2017-01-23', 'price_close': 10.827}, {'coin': 'BTC', 'time_start': '2017-01-24', 'price_close': 10.577}, {'coin': 'BTC', 'time_start': '2017-01-25', 'price_close': 10.50829}, {'coin': 'BTC', 'time_start': '2017-01-26', 'price_close': 10.54}, {'coin': 'BTC', 'time_start': '2017-01-27', 'price_close': 10.58636}, {'coin': 'BTC', 'time_start': '2017-01-28', 'price_close': 10.528}, {'coin': 'BTC', 'time_start': '2017-01-29', 'price_close': 10.43361}, {'coin': 'BTC', 'time_start': '2017-01-30', 'price_close': 10.5}, {'coin': 'BTC', 'time_start': '2017-01-31', 'price_close': 10.66911}, {'coin': 'ETH', 'time_start': '2017-01-01', 'price_close': 8.18}, {'coin': 'ETH', 'time_start': '2017-01-02', 'price_close': 8.38}, {'coin': 'ETH', 'time_start': '2017-01-03', 'price_close': 9.59}, {'coin': 'ETH', 'time_start': '2017-01-04', 'price_close': 11.17}, {'coin': 'ETH', 'time_start': '2017-01-05', 'price_close': 10.31859}, {'coin': 'ETH', 'time_start': '2017-01-06', 'price_close': 10.14}, {'coin': 'ETH', 'time_start': '2017-01-07', 'price_close': 9.92}, {'coin': 'ETH', 'time_start': '2017-01-08', 'price_close': 10.5}, {'coin': 'ETH', 'time_start': '2017-01-09', 'price_close': 10.343}, {'coin': 'ETH', 'time_start': '2017-01-10', 'price_close': 10.522}, {'coin': 'ETH', 'time_start': '2017-01-11', 'price_close': 9.7}, {'coin': 'ETH', 'time_start': '2017-01-12', 'price_close': 9.657}, {'coin': 'ETH', 'time_start': '2017-01-13', 'price_close': 9.699}, {'coin': 'ETH', 'time_start': '2017-01-14', 'price_close': 9.679}, {'coin': 'ETH', 'time_start': '2017-01-15', 'price_close': 9.728}, {'coin': 'ETH', 'time_start': '2017-01-16', 'price_close': 9.53}, {'coin': 'ETH', 'time_start': '2017-01-17', 'price_close': 10.292}, {'coin': 'ETH', 'time_start': '2017-01-18', 'price_close': 10.222}, {'coin': 'ETH', 'time_start': '2017-01-19', 'price_close': 10.44988}, {'coin': 'ETH', 'time_start': '2017-01-20', 'price_close': 10.62001}, {'coin': 'ETH', 'time_start': '2017-01-21', 'price_close': 10.949}, {'coin': 'ETH', 'time_start': '2017-01-22', 'price_close': 10.664}, {'coin': 'ETH', 'time_start': '2017-01-23', 'price_close': 10.827}, {'coin': 'ETH', 'time_start': '2017-01-24', 'price_close': 10.577}, {'coin': 'ETH', 'time_start': '2017-01-25', 'price_close': 10.50829}, {'coin': 'ETH', 'time_start': '2017-01-26', 'price_close': 10.54}, {'coin': 'ETH', 'time_start': '2017-01-27', 'price_close': 10.58636}, {'coin': 'ETH', 'time_start': '2017-01-28', 'price_close': 10.528}, {'coin':  ...
# BTC
# 2017-01-02
# 8.38

# %%
pprint(final_lst)
# Out:
# [{'coin': 'BTC', 'price_close': 8.18, 'time_start': '2017-01-01'},
#  {'coin': 'BTC', 'price_close': 8.38, 'time_start': '2017-01-02'},
#  {'coin': 'BTC', 'price_close': 9.59, 'time_start': '2017-01-03'},
#  {'coin': 'BTC', 'price_close': 11.17, 'time_start': '2017-01-04'},
#  {'coin': 'BTC', 'price_close': 10.31859, 'time_start': '2017-01-05'},
#  {'coin': 'BTC', 'price_close': 10.14, 'time_start': '2017-01-06'},
#  {'coin': 'BTC', 'price_close': 9.92, 'time_start': '2017-01-07'},
#  {'coin': 'BTC', 'price_close': 10.5, 'time_start': '2017-01-08'},
#  {'coin': 'BTC', 'price_close': 10.343, 'time_start': '2017-01-09'},
#  {'coin': 'BTC', 'price_close': 10.522, 'time_start': '2017-01-10'},
#  {'coin': 'BTC', 'price_close': 9.7, 'time_start': '2017-01-11'},
#  {'coin': 'BTC', 'price_close': 9.657, 'time_start': '2017-01-12'},
#  {'coin': 'BTC', 'price_close': 9.699, 'time_start': '2017-01-13'},
#  {'coin': 'BTC', 'price_close': 9.679, 'time_start': '2017-01-14'},
#  {'coin': 'BTC', 'price_close': 9.728, 'time_start': '2017-01-15'},
#  {'coin': 'BTC', 'price_close': 9.53, 'time_start': '2017-01-16'},
#  {'coin': 'BTC', 'price_close': 10.292, 'time_start': '2017-01-17'},
#  {'coin': 'BTC', 'price_close': 10.222, 'time_start': '2017-01-18'},
#  {'coin': 'BTC', 'price_close': 10.44988, 'time_start': '2017-01-19'},
#  {'coin': 'BTC', 'price_close': 10.62001, 'time_start': '2017-01-20'},
#  {'coin': 'BTC', 'price_close': 10.949, 'time_start': '2017-01-21'},
#  {'coin': 'BTC', 'price_close': 10.664, 'time_start': '2017-01-22'},
#  {'coin': 'BTC', 'price_close': 10.827, 'time_start': '2017-01-23'},
#  {'coin': 'BTC', 'price_close': 10.577, 'time_start': '2017-01-24'},
#  {'coin': 'BTC', 'price_close': 10.50829, 'time_start': '2017-01-25'},
#  {'coin': 'BTC', 'price_close': 10.54, 'time_start': '2017-01-26'},
#  {'coin': 'BTC', 'price_close': 10.58636, 'time_start': '2017-01-27'},
#  {'coin': 'BTC', 'price_close': 10.528, 'time_start': '2017-01-28'},
#  {'coin': 'BTC', 'price_close': 10.43361, 'time_start': '2017-01-29'},
#  {'coin': 'BTC', 'price_close': 10.5, 'time_start': '2017-01-30'},
#  {'coin': 'BTC', 'price_close': 10.66911, 'time_start': '2017-01-31'},
#  {'coin': 'ETH', 'price_close': 8.18, 'time_start': '2017-01-01'},
#  {'coin': 'ETH', 'price_close': 8.38, 'time_start': '2017-01-02'},
#  {'coin': 'ETH', 'price_close': 9.59, 'time_start': '2017-01-03'},
#  {'coin': 'ETH', 'price_close': 11.17, 'time_start': '2017-01-04'},
#  {'coin': 'ETH', 'price_close': 10.31859, 'time_start': '2017-01-05'},
#  {'coin': 'ETH', 'price_close': 10.14, 'time_start': '2017-01-06'},
#  {'coin': 'ETH', 'price_close': 9.92, 'time_start': '2017-01-07'},
#  {'coin': 'ETH', 'price_close': 10.5, 'time_start': '2017-01-08'},
#  {'coin': 'ETH', 'price_close': 10.343, 'time_start': '2017-01-09'},
#  {'coin': 'ETH', 'price_close': 10.522, 'time_start': '2017-01-10'},
#  {'coin': 'ETH', 'price_close': 9.7, 'time_start': '2017-01-11'},
#  {'coin': 'ETH', 'price_close': 9.657, 'time_start': '2017-01-12'},
#  {'coin': 'ETH', 'price_close': 9.699, 'time_start': '2017-01-13'},
#  {'coin': 'ETH', 'price_close': 9.679, 'time_start': '2017-01-14'},
#  {'coin': 'ETH', 'price_close': 9.728, 'time_start': '2017-01-15'},
#  {'coin': 'ETH', 'price_close': 9.53, 'time_start': '2017-01-16'},
#  {'coin': 'ETH', 'price_close': 10.292, 'time_start': '2017-01-17'},
#  {'coin': 'ETH', 'price_close': 10.222, 'time_start': '2017-01-18'},
#  {'coin': 'ETH', 'price_close': 10.44988, 'time_start': '2017-01-19'},
#  {'coin': 'ETH', 'price_close': 10.62001, 'time_start': '2017-01-20'},
#  {'coin': 'ETH', 'price_close': 10.949, 'time_start': '2017-01-21'},
#  {'coin': 'ETH', 'price_close': 10.664, 'time_start': '2017-01-22'},
#  {'coin': 'ETH', 'price_close': 10.827, 'time_start': '2017-01-23'},
#  {'coin': 'ETH', 'price_close': 10.577, 'time_start': '2017-01-24'},
#  {'coin': 'ETH', 'price_close': 10.50829, 'time_start': '2017-01-25'},
#  {'coin': 'ETH', 'price_close': 10.54, 'time_start': '2017-01-26'},
#  {'coin': 'ETH', 'price_close': 10.58636, 'time_start': '2017-01-27'},
#  {'coin': 'ETH', 'price_close': 10.528, 'time_start': '2017-01-28'},
#  {'coin': 'ETH', 'price_close': 10.43361, 'time_start': '2017-01-29'},
#  {'coin': 'ETH', 'price_close': 10.5, 'time_start': '2017-01-30'},
#  {'coin': 'ETH', 'price_close': 10.66911, 'time_start': '2017-01-31'}]

# %%
coins_df = pd.DataFrame(final_lst)
coins_df.head()
# Out:
#   coin  price_close  time_start
# 0  BTC      8.18000  2017-01-01
# 1  BTC      8.38000  2017-01-02
# 2  BTC      9.59000  2017-01-03
# 3  BTC     11.17000  2017-01-04
# 4  BTC     10.31859  2017-01-05

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite://', echo=False)

# %%
coins_df.to_sql('coins_tbl', con=engine)
engine.execute("SELECT * FROM coins_tbl").fetchall()
# Out:
# [(0, 'BTC', 8.18, '2017-01-01'),
#  (1, 'BTC', 8.38, '2017-01-02'),
#  (2, 'BTC', 9.59, '2017-01-03'),
#  (3, 'BTC', 11.17, '2017-01-04'),
#  (4, 'BTC', 10.31859, '2017-01-05'),
#  (5, 'BTC', 10.14, '2017-01-06'),
#  (6, 'BTC', 9.92, '2017-01-07'),
#  (7, 'BTC', 10.5, '2017-01-08'),
#  (8, 'BTC', 10.343, '2017-01-09'),
#  (9, 'BTC', 10.522, '2017-01-10'),
#  (10, 'BTC', 9.7, '2017-01-11'),
#  (11, 'BTC', 9.657, '2017-01-12'),
#  (12, 'BTC', 9.699, '2017-01-13'),
#  (13, 'BTC', 9.679, '2017-01-14'),
#  (14, 'BTC', 9.728, '2017-01-15'),
#  (15, 'BTC', 9.53, '2017-01-16'),
#  (16, 'BTC', 10.292, '2017-01-17'),
#  (17, 'BTC', 10.222, '2017-01-18'),
#  (18, 'BTC', 10.44988, '2017-01-19'),
#  (19, 'BTC', 10.62001, '2017-01-20'),
#  (20, 'BTC', 10.949, '2017-01-21'),
#  (21, 'BTC', 10.664, '2017-01-22'),
#  (22, 'BTC', 10.827, '2017-01-23'),
#  (23, 'BTC', 10.577, '2017-01-24'),
#  (24, 'BTC', 10.50829, '2017-01-25'),
#  (25, 'BTC', 10.54, '2017-01-26'),
#  (26, 'BTC', 10.58636, '2017-01-27'),
#  (27, 'BTC', 10.528, '2017-01-28'),
#  (28, 'BTC', 10.43361, '2017-01-29'),
#  (29, 'BTC', 10.5, '2017-01-30'),
#  (30, 'BTC', 10.66911, '2017-01-31'),
#  (31, 'ETH', 8.18, '2017-01-01'),
#  (32, 'ETH', 8.38, '2017-01-02'),
#  (33, 'ETH', 9.59, '2017-01-03'),
#  (34, 'ETH', 11.17, '2017-01-04'),
#  (35, 'ETH', 10.31859, '2017-01-05'),
#  (36, 'ETH', 10.14, '2017-01-06'),
#  (37, 'ETH', 9.92, '2017-01-07'),
#  (38, 'ETH', 10.5, '2017-01-08'),
#  (39, 'ETH', 10.343, '2017-01-09'),
#  (40, 'ETH', 10.522, '2017-01-10'),
#  (41, 'ETH', 9.7, '2017-01-11'),
#  (42, 'ETH', 9.657, '2017-01-12'),
#  (43, 'ETH', 9.699, '2017-01-13'),
#  (44, 'ETH', 9.679, '2017-01-14'),
#  (45, 'ETH', 9.728, '2017-01-15'),
#  (46, 'ETH', 9.53, '2017-01-16'),
#  (47, 'ETH', 10.292, '2017-01-17'),
#  (48, 'ETH', 10.222, '2017-01-18'),
#  (49, 'ETH', 10.44988, '2017-01-19'),
#  (50, 'ETH', 10.62001, '2017-01-20'),
#  (51, 'ETH', 10.949, '2017-01-21'),
#  (52, 'ETH', 10.664, '2017-01-22'),
#  (53, 'ETH', 10.827, '2017-01-23'),
#  (54, 'ETH', 10.577, '2017-01-24'),
#  (55, 'ETH', 10.50829, '2017-01-25'),
#  (56, 'ETH', 10.54, '2017-01-26'),
#  (57, 'ETH', 10.58636, '2017-01-27'),
#  (58, 'ETH', 10.528, '2017-01-28'),
#  (59, 'ETH', 10.43361, '2017-01-29'),
#  (60, 'ETH', 10.5, '2017-01-30'),
#  (61, 'ETH', 10.66911, '2017-01-31')]

# %%
from flask import (
    Flask,
    render_template,
    jsonify,
    request)

from flask_sqlalchemy import SQLAlchemy

app = Flask(__name__)

app.config['SQLALCHEMY_DATABASE_URI'] = "sqlite:///db/db.sqlite"

db = SQLAlchemy(app)

from .models import coinsDB

for i in range(len(final_lst)):

    coin_name = final_lst[i]['coin']
    time_start = final_lst[i]['time_start']
    price_close = final_lst[i]['price_close']

    rec = coinsDB(coin_name=coin_name, time_start=time_start, price_close=price_close)
    db.session.add(rec)
    db.session.commit()


if __name__ == "__main__":
    app.run()
# Out:
# C:\Users\aliqu\AppData\Local\Continuum\anaconda3\envs\py37\lib\site-packages\flask_sqlalchemy\__init__.py:835: FSADeprecationWarning: SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and will be disabled by default in the future.  Set it to True or False to suppress this warning.
#   'SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and '
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-18-31dacb580dd0> in <module>
#      13 db = SQLAlchemy(app)
#      14
# ---> 15 from .models import coinsDB
#      16
#      17 for i in range(len(final_lst)):
#
# ModuleNotFoundError: No module named '__main__.models'; '__main__' is not a package

# %%
@app.route("/send", methods=["GET", "POST"])
def send():
    if request.method == "POST":

        # print(final_lst[0]['coin']) 
        # print(final_lst[0]['time_start']) 
        # print(final_lst[0]['price_close']) 

        for i in range(len(final_lst)):

            coin_name = final_lst[i]['coin']
            time_start = final_lst[i]['time_start']
            price_close = final_lst[i]['price_close']

            rec = coinsDB(coin_name=coin_name, time_start=time_start, price_close=price_close)
            db.session.add(rec)
            db.session.commit()

        return "Thanks for the form data!"

    return render_template("form.html")


@app.route("/api/data")
def list_coins():
    results = db.session.query(coinsDB.coin_name, coinsDB.time_start, coinsDB.price_close).all()

    coin_lst = []
    for result in results:
        coin_lst.append({
            "coin_name": result[0],
            "time_start": result[1],
            "price_close": result[2]
        })
    return jsonify(coin_lst)


@app.route("/")
def home():
    return "Welcome!"


if __name__ == "__main__":
    app.run()


#%%
# Out:
# C:\Users\aliqu\AppData\Local\Continuum\anaconda3\envs\py37\lib\site-packages\flask_sqlalchemy\__init__.py:835: FSADeprecationWarning: SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and will be disabled by default in the future.  Set it to True or False to suppress this warning.
#   'SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and '
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-90ad92e2b17c> in <module>
#      17 # import necessary libraries
#      18
# ---> 19 class coinsDB(db.Model):
#      20     __tablename__ = 'coin'
#      21
#
# <ipython-input-3-90ad92e2b17c> in coinsDB()
#      23     coin_name = db.Column(db.String(64))
#      24     time_start = db.Column(db.String(64))
# ---> 25     price_close = db.Column(db.string(64))
#      26
#      27     # def __repr__(self):
#
# AttributeError: 'SQLAlchemy' object has no attribute 'string'

# %%
    item_dict = [
    {
        "item": "bitcoin",
        "name": "Bitcoin",
        "date": "2009-01-09T20:00:00",
        "price": 0
    },{
            "item": "bitcoin_max",
            "name": "Bitcoin Peak",
            "date": "2017-12-17T20:00:00",
            "price": 19783.06
    },{
            "item": "ethereum",
            "name": "Ethereum",
            "date": "2015-07-30T20:00:00",
            "price": 0
    },{
            "item": "ethereum_max",
            "name": "Ethereum Peak",
            "date": "2018-01-13T20:00:00",
            "price": 1432.88
    },{
            "item": "ps4",
            "name": "PS4",
            "date": "2013-11-15T20:00:00",
            "price": 399
    },{
            "item": "pizza",
            "name": "Bitcoin Pizza",
            "date": "2010-05-22T20:00:00",
            "price": 30
    },{
            "item": "macbook",
            "name": "MacBook Pro 2012",
            "date": "2012-07-30T20:00:00",
            "price": 1199
    },{
            "item": "oculus",
            "name": "Oculus Rift",
            "date": "2016-03-28T20:00:00",
            "price": 599
    },{
            "item": "fiftycent",
            "name": "50 Cent",
            "date": "2014-02-11T20:00:00",
            "price": 400000
    }]

    item_df = pd.DataFrame(item_dict)
    # item_df = item_df.set_index("item")
    item_df
    print(item_df)
# Out:
#                   date          item              name      price
# 0  2009-01-09T20:00:00       bitcoin           Bitcoin       0.00
# 1  2017-12-17T20:00:00   bitcoin_max      Bitcoin Peak   19783.06
# 2  2015-07-30T20:00:00      ethereum          Ethereum       0.00
# 3  2018-01-13T20:00:00  ethereum_max     Ethereum Peak    1432.88
# 4  2013-11-15T20:00:00           ps4               PS4     399.00
# 5  2010-05-22T20:00:00         pizza     Bitcoin Pizza      30.00
# 6  2012-07-30T20:00:00       macbook  MacBook Pro 2012    1199.00
# 7  2016-03-28T20:00:00        oculus       Oculus Rift     599.00
# 8  2014-02-11T20:00:00     fiftycent           50 Cent  400000.00

# %%
from sqlalchemy import create_engine
engine = create_engine('sqlite://', echo=False)
    # engine = create_engine("sqlite:///../database.sqlite")

# %%
item_df.to_sql('items_tbl', con=engine)
    # engine.execute("SELECT * FROM items_tbl").fetchall()




    # engine = create_engine('sqlite://', echo=False)
#     data = engine.execute("SELECT * FROM items_tbl").fetchall()

# %%
engine.execute("SELECT * FROM items_tbl").fetchall()
# Out:
# [(0, '2009-01-09T20:00:00', 'bitcoin', 'Bitcoin', 0.0),
#  (1, '2017-12-17T20:00:00', 'bitcoin_max', 'Bitcoin Peak', 19783.06),
#  (2, '2015-07-30T20:00:00', 'ethereum', 'Ethereum', 0.0),
#  (3, '2018-01-13T20:00:00', 'ethereum_max', 'Ethereum Peak', 1432.88),
#  (4, '2013-11-15T20:00:00', 'ps4', 'PS4', 399.0),
#  (5, '2010-05-22T20:00:00', 'pizza', 'Bitcoin Pizza', 30.0),
#  (6, '2012-07-30T20:00:00', 'macbook', 'MacBook Pro 2012', 1199.0),
#  (7, '2016-03-28T20:00:00', 'oculus', 'Oculus Rift', 599.0),
#  (8, '2014-02-11T20:00:00', 'fiftycent', '50 Cent', 400000.0)]
